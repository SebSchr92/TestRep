# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/MA/Git'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/MA/Git

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/MA/Git

# %%
# !git init
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/MA/Git/.git/

# %%
username = 'SebSchr92'
git_token = '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'
repository = 'TestRep'

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# origin	https://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@github.com/SebSchr92/TestRep.git (fetch)
# origin	https://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@github.com/SebSchr92/TestRep.git (push)

# %%
#!git remote add origin https://SebSchr92:12345@github.com/SebSchr92/MA_Test.git
#!git remote -v

# %%
# !git config --global user.name "SebSchr"
# !git config --global user.email s.schroeppel@gmx.net

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [main 7e9de5c] First commit
#  1 file changed, 1 insertion(+), 1 deletion(-)

# %%
# !git push origin master
# Out:
# error: src refspec master does not match any
# error: failed to push some refs to 'https://SebSchr92:12345@github.com/SebSchr92/MA_Test.git'

# %%
# !echo "# MA_Test" >> README.md
# !git init
# !git add README.md

# !git commit -m "first commit"
# !git branch -M main
# !git remote add origin https://github.com/SebSchr92/MA_Test.git
# !git push -u origin main
# Out:
# Reinitialized existing Git repository in /content/gdrive/MyDrive/Colab Notebooks/MA/Git/.git/
# [main 3220b25] first commit
#  1 file changed, 1 insertion(+)
#  create mode 100644 README.md
# fatal: remote origin already exists.
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/SebSchr92/MA_Test.git/'

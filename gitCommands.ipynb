# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/MA/Git'
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/MA/Git

# %%
# !pwd
# Out:
# /content/gdrive/MyDrive/Colab Notebooks/MA/Git

# %%
# !git init
# Out:
# Initialized empty Git repository in /content/gdrive/MyDrive/Colab Notebooks/MA/Git/.git/

# %%
username = 'SebSchr92'
git_token = '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'
repository = 'MA_Test'

# %%
# !git remote add origin https://{git_token}@github.com/{username}/{repository}.git
# !git remote -v
# Out:
# fatal: remote origin already exists.
# origin	https://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@github.com/SebSchr/MA_Test.git (fetch)
# origin	https://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@github.com/SebSchr/MA_Test.git (push)

# %%
# !git remote add origin https://SebSchr92:12345@github.com/SebSchr92/MA_Test.git
# !git remote -v
# Out:
# origin	https://SebSchr92:12345@github.com/SebSchr92/MA_Test.git (fetch)
# origin	https://SebSchr92:12345@github.com/SebSchr92/MA_Test.git (push)

# %%
# !git config --global user.name "SebSchr"
# !git config --global user.email s.schroeppel@gmx.net

# %%
# !git add .
# !git commit -m 'First commit'
# Out:
# [master (root-commit) 236c683] First commit
#  2 files changed, 2 insertions(+)
#  create mode 100644 Import_Utils.ipynb
#  create mode 100644 gitCommands.ipynb

# %%
# !git push origin master
# Out:
# remote: Support for password authentication was removed on August 13, 2021.
# remote: Please see https://docs.github.com/en/get-started/getting-started-with-git/about-remote-repositories#cloning-with-https-urls for information on currently recommended modes of authentication.
# fatal: Authentication failed for 'https://github.com/SebSchr92/MA_Test.git/'
